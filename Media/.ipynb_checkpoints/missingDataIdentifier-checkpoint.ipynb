# %% [markdown]
# # Identifying Missing Data
#
# This script aims to iterate through a data folder and identify missing parameter combinations, assuming that all combinatorial possibilities must be present
#
# ## Parsing filenames

# %%
import re
import os

# no_silence_parsed_counts = 0 # Keeping track of which pattern was matched
# silence_parsed_counts = 0 # Keeping track of which pattern was matched

# Updated regex pattern to handle both old and new filename formats
pattern = (
    r"EndSim_epsM(-?[\d\.]+)_epsSD(-?[\d\.]+)"
    r"___OpD([a-zA-Z-]+)_OpM(-?[\d\.]+)_OpSD(-?[\d\.]+)"
    r"___Net([a-zA-Z-]+)___NAgents(\d+)___RS(\d+)"
    r"__MedInfF([\d\.]+)___MedD([a-zA-Z-]+)_MedN(\d+)_MedM(-?[\d\.]+)_MedSD(-?[\d\.]+)"
    r"(_SA(-?[\d\.]+)_ST(-?[\d\.]+)_SDO(-?[\d\.]+)_SBB([a-zA-Z]+))?"
)

def parse_filename(filename):
    """Extract parameters from filename using regex with optional silence parameters"""
    # Remove .csv extension before parsing
    base_name = os.path.splitext(filename)[0]
    match = re.search(pattern, base_name)
    
    if match:
        result = {
            # 'filename': filename,
            'epsM': float(match.group(1)),
            'epsSD': float(match.group(2)),
            'OpD': match.group(3),
            'OpM': float(match.group(4)),
            'OpSD': float(match.group(5)),
            'NetworkType': match.group(6),
            'NAgents': int(match.group(7)),
            'RandomSeed': int(match.group(8)),
            'MedInfF': float(match.group(9)),
            'MedD': match.group(10),
            'MedN': int(match.group(11)),
            'MedM': float(match.group(12)),
            'MedSD': float(match.group(13))
        }
        # Check if silence parameters are present
        if match.group(14):  # The entire silence block exists
            # silence_parsed_counts = silence_parsed_counts + 1 # increment the silence parsed counter
            result.update({
                'Silence_Alpha': float(match.group(15)),
                'Silence_Tau': float(match.group(16)),
                'Silence_Delta0': float(match.group(17)),
                'SilenceByBoundary': match.group(18).lower() == 'true'
            })
        else:
            # no_silence_parsed_counts = no_silence_parsed_counts + 1
            # Set default values for silence parameters if not present
            result.update({
                'Silence_Alpha': None,
                'Silence_Tau': None,
                'Silence_Delta0': None,
                'SilenceByBoundary': None
            })
        
        return result
    return None

# Test the parser
test_filenames = [
    "EndSim_epsM0.01_epsSD0.1___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM0.75_MedSD0.1.csv",
    "EndSim_epsM0.01_epsSD0.1___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM0.75_MedSD0.1_SA0.1_ST1_SDO0.75_SBBfalse.csv",
    "EndSim_epsM0.01_epsSD0.1___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM0.75_MedSD0.1_SA0.1_ST1_SDO-0.75_SBBtrue.csv"
]

for filename in test_filenames:
    params = parse_filename(filename)
    print(f"Filename: {filename}")
    print(f"Parsed: {params}\n")
# Out:
# Filename: EndSim_epsM0.01_epsSD0.1___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM0.75_MedSD0.1.csv
# Parsed: {'epsM': 0.01, 'epsSD': 0.1, 'OpD': 'normal', 'OpM': 0.0, 'OpSD': 0.8, 'NetworkType': 'Scale-free', 'NAgents': 1000, 'RandomSeed': 1, 'MedInfF': 0.5, 'MedD': 'deterministic-normal', 'MedN': 10, 'MedM': 0.75, 'MedSD': 0.1, 'Silence_Alpha': None, 'Silence_Tau': None, 'Silence_Delta0': None, 'SilenceByBoundary': None}
#
# Filename: EndSim_epsM0.01_epsSD0.1___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM0.75_MedSD0.1_SA0.1_ST1_SDO0.75_SBBfalse.csv
# Parsed: {'epsM': 0.01, 'epsSD': 0.1, 'OpD': 'normal', 'OpM': 0.0, 'OpSD': 0.8, 'NetworkType': 'Scale-free', 'NAgents': 1000, 'RandomSeed': 1, 'MedInfF': 0.5, 'MedD': 'deterministic-normal', 'MedN': 10, 'MedM': 0.75, 'MedSD': 0.1, 'Silence_Alpha': 0.1, 'Silence_Tau': 1.0, 'Silence_Delta0': 0.75, 'SilenceByBoundary': False}
#
# Filename: EndSim_epsM0.01_epsSD0.1___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM0.75_MedSD0.1_SA0.1_ST1_SDO-0.75_SBBtrue.csv
# Parsed: {'epsM': 0.01, 'epsSD': 0.1, 'OpD': 'normal', 'OpM': 0.0, 'OpSD': 0.8, 'NetworkType': 'Scale-free', 'NAgents': 1000, 'RandomSeed': 1, 'MedInfF': 0.5, 'MedD': 'deterministic-normal', 'MedN': 10, 'MedM': 0.75, 'MedSD': 0.1, 'Silence_Alpha': 0.1, 'Silence_Tau': 1.0, 'Silence_Delta0': -0.75, 'SilenceByBoundary': True}

# %%
import re
import os
import pandas as pd

# Your updated regex pattern
pattern = (
    r"EndSim_epsM(-?[\d\.]+)_epsSD(-?[\d\.]+)"
    r"___OpD([a-zA-Z-]+)_OpM(-?[\d\.]+)_OpSD(-?[\d\.]+)"
    r"___Net([a-zA-Z-]+)___NAgents(\d+)___RS(\d+)"
    r"__MedInfF([\d\.]+)___MedD([a-zA-Z-]+)_MedN(\d+)_MedM(-?[\d\.]+)_MedSD(-?[\d\.]+)"
    r"(_SA(-?[\d\.]+)_ST(-?[\d\.]+)_SDO(-?[\d\.]+)_SBB([a-zA-Z]+))?"
)

def parse_filename_with_detailed_debug(filename):
    """Extract parameters from filename with detailed debugging"""
    base_name = os.path.splitext(filename)[0]
    # print(f"\n🔍 Analyzing: {filename}")
    # print(f"   Base name: {base_name}")
    
    match = re.search(pattern, base_name)
    
    if not match:
        print("   ❌ NO MATCH with main pattern")
        return None
    
    # Check if silence parameters are present
    has_silence = match.group(14) is not None
    
    result = {
        'epsM': float(match.group(1)),
        'epsSD': float(match.group(2)),
        'OpD': match.group(3),
        'OpM': float(match.group(4)),
        'OpSD': float(match.group(5)),
        'NetworkType': match.group(6),
        'NAgents': int(match.group(7)),
        'RandomSeed': int(match.group(8)),
        'MedInfF': float(match.group(9)),
        'MedD': match.group(10),
        'MedN': int(match.group(11)),
        'MedM': float(match.group(12)),
        'MedSD': float(match.group(13)),
        'has_silence_params': has_silence,
        'filename': filename
    }
    
    if has_silence:
        result.update({
            'Silence_Alpha': float(match.group(15)),
            'Silence_Tau': float(match.group(16)),
            'Silence_Delta0': float(match.group(17)),
            'SilenceByBoundary': match.group(18).lower() == 'true'
        })
        # print("   ✅ SILENCE PARAMETERS DETECTED")
        print(f"      SA: {match.group(15)}, ST: {match.group(16)}, SDO: {match.group(17)}, SBB: {match.group(18)}")
    else:
        result.update({
            'Silence_Alpha': None,
            'Silence_Tau': None,
            'Silence_Delta0': None,
            'SilenceByBoundary': None
        })
        # print("   ⚠️ NO SILENCE PARAMETERS DETECTED")
        
        # Debug why silence parameters aren't being detected
        debug_silence_detection(base_name)
    
    return result

def debug_silence_detection(base_name):
    """Debug why silence parameters aren't being detected"""
    print("   🔧 Debugging silence detection...")
    
    # Test individual components
    silence_patterns = {
        'Full silence block': r"_SA[\d\.]+_ST[\d\.]+_SDO[\d\.]+_SBB[a-zA-Z]+",
        'SA only': r"_SA[\d\.]+",
        'ST only': r"_ST[\d\.]+", 
        'SDO only': r"_SDO[\d\.]+",
        'SBB only': r"_SBB[a-zA-Z]+"
    }
    
    for pattern_name, test_pattern in silence_patterns.items():
        match = re.search(test_pattern, base_name)
        if match:
            print(f"      ✅ {pattern_name}: FOUND -> {match.group()}")
        else:
            print(f"      ❌ {pattern_name}: NOT FOUND")
    
    # Check what comes after MedSD
    medsd_section = base_name.split('_MedSD')
    if len(medsd_section) > 1:
        after_medsd = medsd_section[1]
        print(f"   📍 After _MedSD: '{after_medsd}'")
        
        # Check if there's anything that looks like silence parameters but with different formatting
        if any(x in after_medsd for x in ['SA', 'ST', 'SDO', 'SBB']):
            print("   💡 Found potential silence parameter abbreviations in the filename!")
            
        # Show the exact string that should match the silence pattern
        silence_match_candidate = after_medsd.split('___')[0] if '___' in after_medsd else after_medsd
        print(f"   🔍 String that should match silence pattern: '{silence_match_candidate}'")

def analyze_directory_comprehensive(directory):
    """Comprehensive analysis of all files in directory"""
    csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    print(f"📁 Found {len(csv_files)} CSV files in directory: {directory}")
    
    all_params = []
    files_with_silence = []
    files_without_silence = []
    failed_files = []
    
    for i, filename in enumerate(csv_files, 1):
        # print(f"\n{'='*80}")
        # print(f"Processing file {i}/{len(csv_files)}")
        
        params = parse_filename_with_detailed_debug(filename)
        
        if params:
            all_params.append(params)
            if params['has_silence_params']:
                files_with_silence.append(filename)
            else:
                files_without_silence.append(filename)
        else:
            failed_files.append(filename)
    
    # Generate comprehensive report
    print(f"\n{'='*80}")
    print("📊 COMPREHENSIVE ANALYSIS REPORT")
    print(f"{'='*80}")
    
    print(f"\n📈 SUMMARY STATISTICS:")
    print(f"   Total files: {len(csv_files)}")
    print(f"   Successfully parsed: {len(all_params)}")
    print(f"   Files with silence parameters: {len(files_with_silence)}")
    print(f"   Files without silence parameters: {len(files_without_silence)}")
    print(f"   Failed to parse: {len(failed_files)}")
    
    if files_without_silence:
        print(f"\n🔍 FILES WITHOUT SILENCE PARAMETERS (that should have them):")
        print(f"   Count: {len(files_without_silence)}")
        print(f"   Files:")
        for i, filename in enumerate(files_without_silence, 1):
            print(f"     {i:2d}. {filename}")
            
            # Show the problematic part of the filename
            base_name = os.path.splitext(filename)[0]
            medsd_section = base_name.split('_MedSD')
            if len(medsd_section) > 1:
                after_medsd = medsd_section[1].split('___')[0] if '___' in medsd_section[1] else medsd_section[1]
                print(f"         After MedSD: '{after_medsd}'")
    
    if failed_files:
        print(f"\n❌ FILES THAT FAILED TO PARSE:")
        for i, filename in enumerate(failed_files, 1):
            print(f"   {i:2d}. {filename}")
    
    # Convert to DataFrame for further analysis
    if all_params:
        df = pd.DataFrame(all_params)
        
        # Analyze silence parameters
        if 'Silence_Alpha' in df.columns:
            silence_stats = df[['Silence_Alpha', 'Silence_Tau', 'Silence_Delta0', 'SilenceByBoundary']].describe()
            print(f"\n📊 SILENCE PARAMETER STATISTICS:")
            print(silence_stats)
        
        return df, files_with_silence, files_without_silence, failed_files
    
    return None, files_with_silence, files_without_silence, failed_files

# Test specific problematic files
def test_specific_files(file_list, directory):
    """Test specific files that are causing issues"""
    print(f"\n{'='*80}")
    print("🧪 TESTING SPECIFIC PROBLEMATIC FILES")
    print(f"{'='*80}")
    
    for filename in file_list:
        filepath = os.path.join(directory, filename)
        if os.path.exists(filepath):
            parse_filename_with_detailed_debug(filename)
        else:
            print(f"File not found: {filename}")

# Usage
if __name__ == "__main__":
    directory_path = "data/cluster/endsim/Step6_2reps"
    
    # Run comprehensive analysis
    df, with_silence, without_silence, failed = analyze_directory_comprehensive(directory_path)
    
    # If there are files without silence parameters, test them specifically
    if without_silence:
        print(f"\n{'='*80}")
        print("🔬 DETAILED ANALYSIS OF FILES WITHOUT SILENCE PARAMETERS")
        print(f"{'='*80}")
        test_specific_files(without_silence[:5], directory_path)  # Test first 5 files
# Out:
# 📁 Found 102994 CSV files in directory: data/cluster/endsim/Step6_2reps
#
# ================================================================================
# Processing file 1/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO-0.75_SBBfalse
#       SA: 0.1, ST: 1, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 2/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO-0.75_SBBtrue
#       SA: 0.1, ST: 1, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 3/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0.75_SBBfalse
#       SA: 0.1, ST: 1, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 4/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0.75_SBBtrue
#       SA: 0.1, ST: 1, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 5/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0_SBBfalse
#       SA: 0.1, ST: 1, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 6/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST1_SDO0_SBBtrue
#       SA: 0.1, ST: 1, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 7/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO-0.75_SBBfalse
#       SA: 0.1, ST: 5, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 8/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO-0.75_SBBtrue
#       SA: 0.1, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 9/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0.75_SBBfalse
#       SA: 0.1, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 10/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0.75_SBBtrue
#       SA: 0.1, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 11/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0_SBBfalse
#       SA: 0.1, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 12/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST5_SDO0_SBBtrue
#       SA: 0.1, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 13/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO-0.75_SBBfalse
#       SA: 0.1, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 14/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO-0.75_SBBtrue
#       SA: 0.1, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 15/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0.75_SBBfalse
#       SA: 0.1, ST: 9, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 16/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0.75_SBBtrue
#       SA: 0.1, ST: 9, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 17/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0_SBBfalse
#       SA: 0.1, ST: 9, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 18/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.1_ST9_SDO0_SBBtrue
#       SA: 0.1, ST: 9, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 19/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO-0.75_SBBfalse
#       SA: 0.4, ST: 1, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 20/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO-0.75_SBBtrue
#       SA: 0.4, ST: 1, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 21/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0.75_SBBfalse
#       SA: 0.4, ST: 1, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 22/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0.75_SBBtrue
#       SA: 0.4, ST: 1, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 23/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0_SBBfalse
#       SA: 0.4, ST: 1, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 24/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST1_SDO0_SBBtrue
#       SA: 0.4, ST: 1, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 25/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO-0.75_SBBfalse
#       SA: 0.4, ST: 5, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 26/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO-0.75_SBBtrue
#       SA: 0.4, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 27/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0.75_SBBfalse
#       SA: 0.4, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 28/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0.75_SBBtrue
#       SA: 0.4, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 29/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0_SBBfalse
#       SA: 0.4, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 30/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST5_SDO0_SBBtrue
#       SA: 0.4, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 31/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO-0.75_SBBfalse
#       SA: 0.4, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 32/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO-0.75_SBBtrue
#       SA: 0.4, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 33/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0.75_SBBfalse
#       SA: 0.4, ST: 9, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 34/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0.75_SBBtrue
#       SA: 0.4, ST: 9, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 35/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0_SBBfalse
#       SA: 0.4, ST: 9, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 36/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.4_ST9_SDO0_SBBtrue
#       SA: 0.4, ST: 9, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 37/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO-0.75_SBBfalse
#       SA: 0.7, ST: 1, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 38/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO-0.75_SBBtrue
#       SA: 0.7, ST: 1, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 39/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0.75_SBBfalse
#       SA: 0.7, ST: 1, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 40/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0.75_SBBtrue
#       SA: 0.7, ST: 1, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 41/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0_SBBfalse
#       SA: 0.7, ST: 1, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 42/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST1_SDO0_SBBtrue
#       SA: 0.7, ST: 1, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 43/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO-0.75_SBBfalse
#       SA: 0.7, ST: 5, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 44/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO-0.75_SBBtrue
#       SA: 0.7, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 45/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0.75_SBBfalse
#       SA: 0.7, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 46/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0.75_SBBtrue
#       SA: 0.7, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 47/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0_SBBfalse
#       SA: 0.7, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 48/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST5_SDO0_SBBtrue
#       SA: 0.7, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 49/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO-0.75_SBBfalse
#       SA: 0.7, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 50/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO-0.75_SBBtrue
#       SA: 0.7, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 51/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0.75_SBBfalse
#       SA: 0.7, ST: 9, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 52/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0.75_SBBtrue
#       SA: 0.7, ST: 9, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 53/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0_SBBfalse
#       SA: 0.7, ST: 9, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 54/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA0.7_ST9_SDO0_SBBtrue
#       SA: 0.7, ST: 9, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 55/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO-0.75_SBBfalse
#       SA: 1, ST: 1, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 56/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO-0.75_SBBtrue
#       SA: 1, ST: 1, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 57/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0.75_SBBfalse
#       SA: 1, ST: 1, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 58/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0.75_SBBtrue
#       SA: 1, ST: 1, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 59/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0_SBBfalse
#       SA: 1, ST: 1, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 60/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST1_SDO0_SBBtrue
#       SA: 1, ST: 1, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 61/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO-0.75_SBBfalse
#       SA: 1, ST: 5, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 62/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO-0.75_SBBtrue
#       SA: 1, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 63/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0.75_SBBfalse
#       SA: 1, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 64/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0.75_SBBtrue
#       SA: 1, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 65/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0_SBBfalse
#       SA: 1, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 66/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST5_SDO0_SBBtrue
#       SA: 1, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 67/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO-0.75_SBBfalse
#       SA: 1, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 68/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO-0.75_SBBtrue
#       SA: 1, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 69/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0.75_SBBfalse
#       SA: 1, ST: 9, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 70/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0.75_SBBtrue
#       SA: 1, ST: 9, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 71/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0_SBBfalse
#       SA: 1, ST: 9, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 72/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.1_SA1_ST9_SDO0_SBBtrue
#       SA: 1, ST: 9, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 73/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO-0.75_SBBfalse
#       SA: 0.1, ST: 1, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 74/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO-0.75_SBBtrue
#       SA: 0.1, ST: 1, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 75/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0.75_SBBfalse
#       SA: 0.1, ST: 1, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 76/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0.75_SBBtrue
#       SA: 0.1, ST: 1, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 77/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0_SBBfalse
#       SA: 0.1, ST: 1, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 78/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST1_SDO0_SBBtrue
#       SA: 0.1, ST: 1, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 79/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO-0.75_SBBfalse
#       SA: 0.1, ST: 5, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 80/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO-0.75_SBBtrue
#       SA: 0.1, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 81/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0.75_SBBfalse
#       SA: 0.1, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 82/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0.75_SBBtrue
#       SA: 0.1, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 83/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0_SBBfalse
#       SA: 0.1, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 84/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST5_SDO0_SBBtrue
#       SA: 0.1, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 85/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO-0.75_SBBfalse
#       SA: 0.1, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 86/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO-0.75_SBBtrue
#       SA: 0.1, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 87/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO0.75_SBBfalse
#       SA: 0.1, ST: 9, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 88/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO0.75_SBBtrue
#       SA: 0.1, ST: 9, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 89/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF0.5___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.4_SA0.1_ST9_SDO0_SBBfalse
#       SA: 0.1, ST: 9, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 90/102994
#
# ...
# Processing file 1895/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO-0.75_SBBtrue
#       SA: 0.4, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 1896/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0.75_SBBfalse
#       SA: 0.4, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 1897/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0.75_SBBtrue
#       SA: 0.4, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 1898/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0_SBBfalse
#       SA: 0.4, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 1899/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST5_SDO0_SBBtrue
#       SA: 0.4, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 1900/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO-0.75_SBBfalse
#       SA: 0.4, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 1901/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO-0.75_SBBtrue
#       SA: 0.4, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 1902/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0.75_SBBfalse
#       SA: 0.4, ST: 9, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 1903/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0.75_SBBtrue
#       SA: 0.4, ST: 9, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 1904/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0_SBBfalse
#       SA: 0.4, ST: 9, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 1905/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.4_ST9_SDO0_SBBtrue
#       SA: 0.4, ST: 9, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 1906/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO-0.75_SBBfalse
#       SA: 0.7, ST: 1, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 1907/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO-0.75_SBBtrue
#       SA: 0.7, ST: 1, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 1908/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0.75_SBBfalse
#       SA: 0.7, ST: 1, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 1909/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0.75_SBBtrue
#       SA: 0.7, ST: 1, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 1910/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0_SBBfalse
#       SA: 0.7, ST: 1, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 1911/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST1_SDO0_SBBtrue
#       SA: 0.7, ST: 1, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 1912/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO-0.75_SBBfalse
#       SA: 0.7, ST: 5, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 1913/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO-0.75_SBBtrue
#       SA: 0.7, ST: 5, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 1914/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0.75_SBBfalse
#       SA: 0.7, ST: 5, SDO: 0.75, SBB: false
#
# ================================================================================
# Processing file 1915/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0.75_SBBtrue
#       SA: 0.7, ST: 5, SDO: 0.75, SBB: true
#
# ================================================================================
# Processing file 1916/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0_SBBfalse
#       SA: 0.7, ST: 5, SDO: 0, SBB: false
#
# ================================================================================
# Processing file 1917/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST5_SDO0_SBBtrue
#       SA: 0.7, ST: 5, SDO: 0, SBB: true
#
# ================================================================================
# Processing file 1918/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST9_SDO-0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST9_SDO-0.75_SBBfalse
#       SA: 0.7, ST: 9, SDO: -0.75, SBB: false
#
# ================================================================================
# Processing file 1919/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST9_SDO-0.75_SBBtrue.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST9_SDO-0.75_SBBtrue
#       SA: 0.7, ST: 9, SDO: -0.75, SBB: true
#
# ================================================================================
# Processing file 1920/102994
#
# 🔍 Analyzing: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST9_SDO0.75_SBBfalse.csv
#    Base name: EndSim_epsM0.01_epsSD0.05___OpDnormal_OpM0_OpSD0.8___NetScale-free___NAgents1000___RS1__MedInfF1___MedDdeterministic-normal_MedN10_MedM-0.75_MedSD0.7_SA0.7_ST9_SDO0.75_SBBfalse
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 193
#     190 directory_path = "data/cluster/endsim/Step6_2reps"
#     192 # Run comprehensive analysis
# --> 193 df, with_silence, without_silence, failed = analyze_directory_comprehensive(directory_path)
#     195 # If there are files without silence parameters, test them specifically
#     196 if without_silence:
#
# Cell In[40], line 118, in analyze_directory_comprehensive(directory)
#     115 print(f"\n{'='*80}")
#     116 print(f"Processing file {i}/{len(csv_files)}")
# --> 118 params = parse_filename_with_detailed_debug(filename)
#     120 if params:
#     121     all_params.append(params)
#
# Cell In[40], line 18, in parse_filename_with_detailed_debug(filename)
#      16 base_name = os.path.splitext(filename)[0]
#      17 print(f"\n🔍 Analyzing: {filename}")
# ---> 18 print(f"   Base name: {base_name}")
#      20 match = re.search(pattern, base_name)
#      22 if not match:
#
# File ~\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3043 def write(data, *args, **kwargs):
#    3044     """Write data to both the original destination and the capture dictionary."""
# -> 3045     result = original_write(data, *args, **kwargs)
#    3046     if any(
#    3047         [
#    3048             self.display_pub.is_publishing,
#    (...)   3051         ]
#    3052     ):
#    3053         return result
#
# File ~\miniconda3\Lib\site-packages\ipykernel\iostream.py:655, in OutStream.write(self, string)
#     647                     return
#     649             self.session.send(
#     650                 self.pub_thread,
#     651                 msg,
#     652                 ident=self.topic,
#     653             )
# --> 655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)    662
#     663     """
#     664     parent = self.parent_header
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 has_silence_params
#
# NameError: name 'has_silence_params' is not defined

# %% [markdown]
# ## Expected combinations
#
# ```
# expected_combinations = {
#         'epsM': [0.01, 0.06, 0.11, 0.16, 0.21, 0.26],
#         'epsSD': [0.05, 0.1, 0.15],
#         'OpM': [0],
#         'OpSD': [0.8],
#         'MedInfF': [0, 0.5, 1],
#         'MedM': [-0.75, 0, 0.75],
#         'MedSD': [0.1, 0.4, 0.7, 1],
#         'Silence_Alpha': [0.1, 0.4, 0.7, 1],
#         'Silence_Tau': [1, 5, 9],
#         'Silence_Delta0': [-0.75, 0, 0.75],
#         'SilenceByBoundary': [True, False]
#     }
# ```
